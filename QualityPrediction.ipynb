# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_csv('data.csv',decimal=",")

# %%
data.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
# ...

# %%
data.shape
# Out:
# (737453, 24)

# %%
data.columns
# Out:
# Index(['date', '% Iron Feed', '% Silica Feed', 'Starch Flow', 'Amina Flow',
#        'Ore Pulp Flow', 'Ore Pulp pH', 'Ore Pulp Density',
#        'Flotation Column 01 Air Flow', 'Flotation Column 02 Air Flow',
#        'Flotation Column 03 Air Flow', 'Flotation Column 04 Air Flow',
#        'Flotation Column 05 Air Flow', 'Flotation Column 06 Air Flow',
#        'Flotation Column 07 Air Flow', 'Flotation Column 01 Level',
#        'Flotation Column 02 Level', 'Flotation Column 03 Level',
#        'Flotation Column 04 Level', 'Flotation Column 05 Level',
#        'Flotation Column 06 Level', 'Flotation Column 07 Level',
#        '% Iron Concentrate', '% Silica Concentrate'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# date                            0
# % Iron Feed                     0
# % Silica Feed                   0
# Starch Flow                     0
# Amina Flow                      0
# Ore Pulp Flow                   0
# Ore Pulp pH                     0
# Ore Pulp Density                0
# Flotation Column 01 Air Flow    0
# Flotation Column 02 Air Flow    0
# Flotation Column 03 Air Flow    0
# Flotation Column 04 Air Flow    0
# Flotation Column 05 Air Flow    0
# Flotation Column 06 Air Flow    0
# Flotation Column 07 Air Flow    0
# Flotation Column 01 Level       0
# Flotation Column 02 Level       0
# Flotation Column 03 Level       0
# Flotation Column 04 Level       0
# Flotation Column 05 Level       0
# Flotation Column 06 Level       0
# Flotation Column 07 Level       0
# % Iron Concentrate              0
# % Silica Concentrate            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
# date                            737453 non-null object
# % Iron Feed                     737453 non-null float64
# % Silica Feed                   737453 non-null float64
# Starch Flow                     737453 non-null float64
# Amina Flow                      737453 non-null float64
# Ore Pulp Flow                   737453 non-null float64
# Ore Pulp pH                     737453 non-null float64
# Ore Pulp Density                737453 non-null float64
# Flotation Column 01 Air Flow    737453 non-null float64
# Flotation Column 02 Air Flow    737453 non-null float64
# Flotation Column 03 Air Flow    737453 non-null float64
# Flotation Column 04 Air Flow    737453 non-null float64
# Flotation Column 05 Air Flow    737453 non-null float64
# Flotation Column 06 Air Flow    737453 non-null float64
# Flotation Column 07 Air Flow    737453 non-null float64
# ...

# %%
data['date'] = pd.to_datetime(data['date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737453 entries, 0 to 737452
# Data columns (total 24 columns):
# date                            737453 non-null datetime64[ns]
# % Iron Feed                     737453 non-null float64
# % Silica Feed                   737453 non-null float64
# Starch Flow                     737453 non-null float64
# Amina Flow                      737453 non-null float64
# Ore Pulp Flow                   737453 non-null float64
# Ore Pulp pH                     737453 non-null float64
# Ore Pulp Density                737453 non-null float64
# Flotation Column 01 Air Flow    737453 non-null float64
# Flotation Column 02 Air Flow    737453 non-null float64
# Flotation Column 03 Air Flow    737453 non-null float64
# Flotation Column 04 Air Flow    737453 non-null float64
# Flotation Column 05 Air Flow    737453 non-null float64
# Flotation Column 06 Air Flow    737453 non-null float64
# Flotation Column 07 Air Flow    737453 non-null float64
# ...

# %%
data.head()
# Out:
#                  date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0 2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1 2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2 2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3 2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4 2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
# ...

# %%
data.index = data['date']

# %%
data.head()
# Out:
#                                    date  % Iron Feed  % Silica Feed  \
# date
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
#
#                      Starch Flow  Amina Flow  Ore Pulp Flow  Ore Pulp pH  \
# date
# 2017-03-10 01:00:00      3019.53     557.434        395.713      10.0664
# 2017-03-10 01:00:00      3024.41     563.965        397.383      10.0672
# 2017-03-10 01:00:00      3043.46     568.054        399.668      10.0680
# 2017-03-10 01:00:00      3047.36     568.665        397.939      10.0689
# 2017-03-10 01:00:00      3033.69     558.167        400.254      10.0697
#
#                      Ore Pulp Density  Flotation Column 01 Air Flow  \
# date
# ...

# %%
X = data.index

# %%
iron = data["% Iron Concentrate"].values

# %%
plt.plot(X,data["% Iron Concentrate"])
plt.legend()

# %%
silica = data["% Silica Concentrate"].values

# %%
plt.plot(X,silica)

# %%
df = data[:100000]

# %%
plt.plot(df.index,df["% Iron Concentrate"])

# %%
df2 = data[26814:126814]

# %%
plt.plot(df2.index,df2["% Iron Concentrate"])

# %%
df2.shape
# Out:
# (100000, 24)

# %%
np.random.seed(7)

# %%
sns.set(style="ticks", color_codes=True)

# %%
df2[:100].shape
# Out:
# (100, 24)

# %% [markdown]
# # correlation

# %%
plt.plot(df2[df2.columns[0]],df2[df2.columns[23]])
plt.legend()

# %%
plt.plot(df2[df2.columns[0]],df2[df2.columns[22]])
plt.legend()

# %% [markdown]
# # %Iron Concentrate vs different attributes

# %%
for i in range(1,24):
    plt.figure()
    plt.plot(df2[df2.columns[22]],df2[df2.columns[i]],'o')
    plt.legend()
# Out:
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# # %Silica concentrate vs different attributes

# %%
for i in range(1,24):
    plt.figure()
    plt.plot(df2[df2.columns[23]],df2[df2.columns[i]],'o')
    plt.legend()
# Out:
# F:\Anaconda3\lib\site-packages\matplotlib\pyplot.py:524: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
df2.shape
# Out:
# (100000, 24)

# %% [markdown]
# # Multilayer Perceptron

# %%
train_size = int(len(df2)*0.7)
test_size = len(df2)-train_size
train,test = df2[0:train_size],df2[train_size:len(df2)]

# %%
train.shape
# Out:
# (70000, 24)

# %%
test.shape
# Out:
# (30000, 24)

# %% [markdown]
# # Autocorrelation

# %%
from pandas.tools.plotting import autocorrelation_plot

# %%
autocorrelation_plot(df2["% Iron Concentrate"])

# %%
def create_dataset(dataset,column,look_back=1):
    dataX = dataset[:len(dataset)-look_back][column]
    dataY = dataset[look_back:][column]
    return np.array(dataX),np.array(dataY)

# %%
trainX,trainY = create_dataset(train,"% Iron Concentrate",2)

# %%
testX,testY = create_dataset(test,"% Iron Concentrate",2)

# %% [markdown]
# # Multilayer Perceptron model

# %%
model = Sequential()
model.add(Dense(8,input_dim=look_back,activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(trainX,trainY,epochs=20,batch_size=2,verbose=2)
# Out:
# Epoch 1/20
#  - 53s - loss: 0.2066
# Epoch 2/20
#  - 52s - loss: 0.0113
# Epoch 3/20
#  - 46s - loss: 0.0110
# Epoch 4/20
#  - 49s - loss: 0.0110
# Epoch 5/20
#  - 49s - loss: 0.0106
# Epoch 6/20
#  - 51s - loss: 0.0105
# Epoch 7/20
#  - 54s - loss: 0.0104
# Epoch 8/20
#  - 62s - loss: 0.0104
# Epoch 9/20
#  - 54s - loss: 0.0105
# Epoch 10/20
#  - 55s - loss: 0.0105
# Epoch 11/20
#  - 55s - loss: 0.0105
# Epoch 12/20
#  - 51s - loss: 0.0103
# Epoch 13/20
#  - 50s - loss: 0.0104
# Epoch 14/20
#  - 51s - loss: 0.0104
# Epoch 15/20
#  - 51s - loss: 0.0104
# Epoch 16/20
#  - 62s - loss: 0.0104
# Epoch 17/20
#  - 60s - loss: 0.0105
# Epoch 18/20
#  - 49s - loss: 0.0105
# Epoch 19/20
#  - 47s - loss: 0.0104
# Epoch 20/20
#  - 47s - loss: 0.0103

# %%
trainScore = model.evaluate(trainX,trainY,verbose=0)

# %%
import math
print('Train Score: %.2f MSE (%.2f RMSE)' %(trainScore,math.sqrt(trainScore)))
# Out:
# Train Score: 0.01 MSE (0.08 RMSE)

# %%
testScore = model.evaluate(testX, testY, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Test Score: 0.01 MSE (0.08 RMSE)

# %%
trainPredict = model.predict(trainX)

# %%
testPredict = model.predict(testX)

# %%
print(testX.shape)
print(testPredict.shape)
# Out:
# (29998,)
# (29998, 1)

# %%
type(testX)
# Out:
# numpy.ndarray

# %%
plt.plot(testX,'r',label='shar')
# plt.plot(testPredict,'b',label='par')
plt.legend()
# plt.show()

# %%
# plt.plot(testX,'r',label='shar')
plt.plot(testPredict,'b',label='par')
plt.legend()
# plt.show()

# %%
data.head()
# Out:
#                                    date  % Iron Feed  % Silica Feed  \
# date
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
# 2017-03-10 01:00:00 2017-03-10 01:00:00         55.2          16.98
#
#                      Starch Flow  Amina Flow  Ore Pulp Flow  Ore Pulp pH  \
# date
# 2017-03-10 01:00:00      3019.53     557.434        395.713      10.0664
# 2017-03-10 01:00:00      3024.41     563.965        397.383      10.0672
# 2017-03-10 01:00:00      3043.46     568.054        399.668      10.0680
# 2017-03-10 01:00:00      3047.36     568.665        397.939      10.0689
# 2017-03-10 01:00:00      3033.69     558.167        400.254      10.0697
#
#                      Ore Pulp Density  Flotation Column 01 Air Flow  \
# date
# ...

# %%
data.tail()
# Out:
#                                    date  % Iron Feed  % Silica Feed  \
# date
# 2017-09-09 23:00:00 2017-09-09 23:00:00        49.75           23.2
# 2017-09-09 23:00:00 2017-09-09 23:00:00        49.75           23.2
# 2017-09-09 23:00:00 2017-09-09 23:00:00        49.75           23.2
# 2017-09-09 23:00:00 2017-09-09 23:00:00        49.75           23.2
# 2017-09-09 23:00:00 2017-09-09 23:00:00        49.75           23.2
#
#                      Starch Flow  Amina Flow  Ore Pulp Flow  Ore Pulp pH  \
# date
# 2017-09-09 23:00:00      2710.94     441.052        386.570      9.62129
# 2017-09-09 23:00:00      2692.01     473.436        384.939      9.62063
# 2017-09-09 23:00:00      2692.20     500.488        383.496      9.61874
# 2017-09-09 23:00:00      1164.12     491.548        384.976      9.61686
# 2017-09-09 23:00:00      1164.12     468.019        384.801      9.61497
#
#                      Ore Pulp Density  Flotation Column 01 Air Flow  \
# date
# ...
